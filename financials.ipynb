# %%
import pandas as pd
import yfinance as yf

# %%
ticker = yf.Ticker('TCS.BO')
df_qcsf = ticker.quarterly_cashflow

# %%
df_qcsf.iloc[:,:1]
# Out:
#                                              2024-09-30
# Free Cash Flow                           100190000000.0
# Capital Expenditure                       -8120000000.0
# End Cash Position                         81550000000.0
# Beginning Cash Position                   76690000000.0
# Effect Of Exchange Rate Changes            2330000000.0
# Changes In Cash                            2530000000.0
# Financing Cash Flow                      -44020000000.0
# Interest Paid Cff                                   NaN
# Cash Dividends Paid                      -36180000000.0
# Investing Cash Flow                      -61760000000.0
# Net Other Investing Changes                         0.0
# Interest Received Cfi                               NaN
# Dividends Received Cfi                              NaN
# Net Investment Purchase And Sale         -66870000000.0
# Sale Of Investment                       325510000000.0
# Purchase Of Investment                  -392380000000.0
# ...

# %%
# Out:
# None
